# %%
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis

# Import Datasets
uci_diabetes = pd.read_csv("uci_diabetes (3).csv")
pima_diabetes = pd.read_csv("pima_diabetes (3).csv")

# Display Dataset Samples
print("UCI Diabetes Dataset Sample:")
print(uci_diabetes.head())

print("\nPima Indians Diabetes Dataset Sample:")
print(pima_diabetes.head())

# Define Relevant Numerical Columns
numerical_columns = [
    "Glucose",
    "BloodPressure",
    "SkinThickness",
    "Insulin",
    "BMI",
    "DiabetesPedigreeFunction",
    "Age"
]

# Univariate Analysis Function
def univariate_analysis(df, columns):

    stats = {}

    for col in columns:
        stats[col] = {
            "Mean": np.mean(df[col]),
            "Median": np.median(df[col]),
            "Mode": df[col].mode()[0],
            "Variance": np.var(df[col], ddof=1),
            "Standard Deviation": np.std(df[col], ddof=1),
            "Skewness": skew(df[col]),
            "Kurtosis": kurtosis(df[col])
        }

    return pd.DataFrame(stats).T

# Perform Univariate Analysis
uci_stats = univariate_analysis(uci_diabetes, numerical_columns)
pima_stats = univariate_analysis(pima_diabetes, numerical_columns)

# Display Results
print("\nUCI Diabetes Dataset Statistics:")
print(uci_stats)

print("\nPima Indians Diabetes Dataset Statistics:")
print(pima_stats)
# Out:
# UCI Diabetes Dataset Sample:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      120             70             30      100  32.5
# 1            5      145             82             28      140  36.8
# 2            1       95             60             22       80  24.7
# 3            7      180             88             35      200  40.2
# 4            3      130             76             27      120  31.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                      0.45   29        0
# 1                      0.72   45        1
# 2                      0.18   23        0
# 3                      1.05   52        1
# 4                      0.52   34        0
#
# Pima Indians Diabetes Dataset Sample:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
#
# UCI Diabetes Dataset Statistics:
#                              Mean   Median   Mode     Variance  \
# Glucose                   139.950  137.500  95.00   964.786842
# BloodPressure              77.900   79.000  60.00   110.726316
# SkinThickness              29.950   30.000  30.00    36.050000
# Insulin                   156.800  145.000  70.00  5140.168421
# BMI                        34.410   34.050  23.90    45.567263
# DiabetesPedigreeFunction    0.742    0.665   0.14     0.219691
# Age                        40.000   38.500  21.00   174.631579
#
#                           Standard Deviation  Skewness  Kurtosis
# Glucose                            31.061018  0.104203 -1.318970
# BloodPressure                      10.522657 -0.106263 -1.323494
# SkinThickness                       6.004165 -0.006051 -0.998371
# Insulin                            71.694968  0.543400 -0.922191
# BMI                                 6.750353  0.001554 -1.209590
# DiabetesPedigreeFunction            0.468712  0.486645 -0.884651
# Age                                13.214824  0.145309 -1.321403
#
# Pima Indians Diabetes Dataset Statistics:
#                                 Mean   Median    Mode      Variance  \
# Glucose                   136.333333  137.000  78.000   1473.380952
# BloodPressure              65.066667   70.000  66.000    521.638095
# SkinThickness              16.066667   19.000   0.000    277.638095
# Insulin                   127.600000    0.000   0.000  60126.257143
# BMI                        29.046667   30.100   0.000     94.822667
# DiabetesPedigreeFunction    0.548800    0.351   0.134      0.343998
# Age                        39.333333   33.000  30.000    166.952381
#
#                           Standard Deviation  Skewness  Kurtosis
# Glucose                            38.384645  0.069057 -1.159801
# BloodPressure                      22.839398 -1.489967  2.591434
# SkinThickness                      16.662476  0.250338 -1.489526
# Insulin                           245.206560  2.125390  3.319697
# BMI                                 9.737693 -1.627494  3.519886
# DiabetesPedigreeFunction            0.586514  2.062622  3.408398
# Age                                12.921005  0.308093 -1.514787
