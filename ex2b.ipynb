# %%
import pandas as pd
import numpy as np

# Load dataset into a DataFrame
df = pd.read_csv('data.csv')

# Display first and last few rows
print("First 5 rows:\n", df.head())
print("Last 5 rows:\n", df.tail())

# Check data types and general info
df.info()

# Summary statistics
print("Summary statistics:\n", df.describe())

# Handle missing values (Numeric columns only)
df.fillna(df.mean(numeric_only=True), inplace=True)

# Create a new column
df['new_column'] = df['existing_column'] * 2

# Create a Series and perform operations
series = df['existing_column']
print("Series addition:\n", series + 10)

# Filter rows based on conditions
filtered_df = df[
    (df['existing_column'] > 50) &
    (df['another_column'] < 100)
]
print("Filtered DataFrame:\n", filtered_df)

# Grouping and aggregation
grouped = df.groupby('category_column')['numeric_column'].mean()
print("Grouped mean:\n", grouped)

# Sorting
df_sorted = df.sort_values(by='numeric_column', ascending=False)
print("Sorted DataFrame:\n", df_sorted)

# Boolean masking
masked_df = df[df['numeric_column'] > df['numeric_column'].median()]
print("Masked DataFrame:\n", masked_df)

# Remove duplicates and drop missing values
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# Create a new DataFrame with selected columns
subset_df = df[['column1', 'column2']]

# Save the new DataFrame to a CSV file
subset_df.to_csv('filtered_data.csv', index=False)

# Compute summary statistics
print("Total sum:", df['numeric_column'].sum())
print("Mean:", df['numeric_column'].mean())
print("Standard Deviation:", df['numeric_column'].std())
# Out:
# First 5 rows:
#     existing_column  another_column category_column  numeric_column column1  \
# 0               45             120               A             500   Apple
# 1               60              80               B             620  Banana
# 2               75              90               A             700  Orange
# 3               30             110               C             450  Grapes
# 4               85              70               B             900   Mango
#
#   column2
# 0     Red
# 1  Yellow
# 2  Orange
# 3   Green
# 4  Yellow
# Last 5 rows:
#      existing_column  another_column category_column  numeric_column  \
# 10               65              99               B             720
# 11               50             105               A             600
# 12               80              65               C             850
# 13               35             140               B             400
# 14               90              75               A             950
#
#       column1 column2
# 10      Peach    Pink
# 11       Plum  Purple
# 12      Lemon  Yellow
# 13       Lime   Green
# 14  Pineapple   Brown
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   existing_column  15 non-null     int64
#  1   another_column   15 non-null     int64
#  2   category_column  15 non-null     object
#  3   numeric_column   15 non-null     int64
#  4   column1          15 non-null     object
#  5   column2          15 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 852.0+ bytes
# Summary statistics:
#         existing_column  another_column  numeric_column
# count        15.000000       15.000000       15.000000
# mean         59.666667       98.266667      656.666667
# std          22.949219       27.491471      206.662826
# min          20.000000       60.000000      300.000000
# 25%          42.500000       77.500000      490.000000
# 50%          60.000000       95.000000      650.000000
# 75%          77.500000      115.000000      800.000000
# max          95.000000      150.000000      980.000000
# Series addition:
#  0      55
# 1      70
# 2      85
# 3      40
# 4      95
# 5      65
# 6      50
# 7     105
# 8      30
# 9      80
# 10     75
# 11     60
# 12     90
# 13     45
# 14    100
# Name: existing_column, dtype: int64
# Filtered DataFrame:
#      existing_column  another_column category_column  numeric_column  \
# 1                60              80               B             620
# 2                75              90               A             700
# 4                85              70               B             900
# 5                55              95               A             650
# 7                95              60               B             980
# 9                70              85               C             750
# 10               65              99               B             720
# 12               80              65               C             850
# 14               90              75               A             950
#
#       column1 column2  new_column
# 1      Banana  Yellow         120
# 2      Orange  Orange         150
# 4       Mango  Yellow         170
# 5        Kiwi   Brown         110
# 7      Papaya  Orange         190
# 9      Cherry     Red         140
# 10      Peach    Pink         130
# 12      Lemon  Yellow         160
# 14  Pineapple   Brown         180
# Grouped mean:
#  category_column
# A    616.666667
# B    724.000000
# C    632.500000
# Name: numeric_column, dtype: float64
# Sorted DataFrame:
#      existing_column  another_column category_column  numeric_column  \
# 7                95              60               B             980
# 14               90              75               A             950
# 4                85              70               B             900
# 12               80              65               C             850
# 9                70              85               C             750
# 10               65              99               B             720
# 2                75              90               A             700
# 5                55              95               A             650
# 1                60              80               B             620
# 11               50             105               A             600
# 0                45             120               A             500
# 6                40             130               C             480
# 3                30             110               C             450
# 13               35             140               B             400
# 8                20             150               A             300
#
#       column1 column2  new_column
# 7      Papaya  Orange         190
# 14  Pineapple   Brown         180
# 4       Mango  Yellow         170
# 12      Lemon  Yellow         160
# 9      Cherry     Red         140
# 10      Peach    Pink         130
# 2      Orange  Orange         150
# 5        Kiwi   Brown         110
# 1      Banana  Yellow         120
# 11       Plum  Purple         100
# 0       Apple     Red          90
# 6        Pear   Green          80
# 3      Grapes   Green          60
# 13       Lime   Green          70
# 8       Guava   Green          40
# Masked DataFrame:
#      existing_column  another_column category_column  numeric_column  \
# 2                75              90               A             700
# 4                85              70               B             900
# 7                95              60               B             980
# 9                70              85               C             750
# 10               65              99               B             720
# 12               80              65               C             850
# 14               90              75               A             950
#
#       column1 column2  new_column
# 2      Orange  Orange         150
# 4       Mango  Yellow         170
# 7      Papaya  Orange         190
# 9      Cherry     Red         140
# 10      Peach    Pink         130
# 12      Lemon  Yellow         160
# 14  Pineapple   Brown         180
# Total sum: 9850
# Mean: 656.6666666666666
# Standard Deviation: 206.66282638521088
